# %%
# !pip install requests json pandas
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json

# %%
import requests
import json
import pandas as pd

SERVICE_KEY = '55546a414d79616735317868654874'
url = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/1/1000/2025/11560'
req = requests.get(url)

req
# Out:
# <Response [200]>

# %%
content = req.json()
content
# Out:
# {'tbLnOpendataRtmsV': {'list_total_count': 831,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'RCPT_YR': '2025',
#     'CGG_CD': '11560',
#     'CGG_NM': '영등포구',
#     'STDG_CD': '13200',
#     'STDG_NM': '신길동',
#     'LOTNO_SE': '1',
#     'LOTNO_SE_NM': '대지',
#     'MNO': '4950',
#     'SNO': '0000',
#     'BLDG_NM': '래미안에스티움',
#     'CTRT_DAY': '20250312',
#     'THING_AMT': '155000',
#     'ARCH_AREA': 84.97,
#     'LAND_AREA': 0.0,
#     'FLR': 26.0,
#     'RGHT_SE': '',
#     'RTRCN_DAY': '',
#     'ARCH_YR': '2017',
#     'BLDG_USG': '아파트',
#     'DCLR_SE': '중개거래',
#     'OPBIZ_RESTAGNT_SGG_NM': '서울 영등포구'},
#    {'RCPT_YR': '2025',
#     'CGG_CD': '11560',
#     'CGG_NM': '영등포구',
#     'STDG_CD': '12100',
#     'STDG_NM': '문래동3가',
#     'LOTNO_SE': '1',
#     'LOTNO_SE_NM': '대지',
#     'MNO': '0077',
#     'SNO': '0002',
#     'BLDG_NM': '문래공원한신',
#     'CTRT_DAY': '20250308',
#     'THING_AMT': '112000',
#     'ARCH_AREA': 79.46,
# ...

# %%
cons = content['tbLnOpendataRtmsV']['row']
for i, con in enumerate(cons):
    print(str(i + 1) + ' ' + con['CTRT_DAY'] + ' ' + con['CGG_NM'] + ' ' + con['STDG_NM'] + ' ' + con['BLDG_NM'] + ' ' + con['THING_AMT'] + '만원')
# Out:
# 1 20250312 영등포구 신길동 래미안에스티움 155000만원
# 2 20250308 영등포구 문래동3가 문래공원한신 112000만원
# 3 20250308 영등포구 문래동6가 현대2차 58500만원
# 4 20250308 영등포구 여의도동 삼부 330000만원
# 5 20250308 영등포구 당산동5가 당산역 한강포스빌 18000만원
# 6 20250307 영등포구 여의도동 대교 240000만원
# 7 20250307 영등포구 문래동6가 대원 69000만원
# 8 20250307 영등포구 당산동5가 당산효성1차 141000만원
# 9 20250307 영등포구 당산동6가 삼보하이츠(237-92) 27000만원
# 10 20250307 영등포구 양평동6가 양평도담빌E 24000만원
# 11 20250307 영등포구 당산동3가 리앤나빌리지 13300만원
# 12 20250306 영등포구 신길동 삼성 69000만원
# 13 20250306 영등포구 당산동5가 당산삼성래미안4차 175000만원
# 14 20250306 영등포구 영등포동7가 하우스퀘어 26000만원
# 15 20250306 영등포구 여의도동 시범 230000만원
# 16 20250306 영등포구 영등포동7가 블리스 다임빌 30000만원
# 17 20250305 영등포구 여의도동 수정 280000만원
# 18 20250305 영등포구 양평동2가 양평벽산블루밍 71100만원
# 19 20250305 영등포구 여의도동 S-TRENUE 166000만원
# 20 20250305 영등포구 신길동 삼성래미안 73000만원
# 21 20250305 영등포구 양평동6가 한양맨션4동 48000만원
# 22 20250305 영등포구 영등포동2가 리버타워 오피스텔 6800만원
# 23 20250305 영등포구 영등포동7가 아크로타워스퀘어 163000만원
# 24 20250304 영등포구 여의도동 브라이튼여의도 369100만원
# 25 20250304 영등포구 양평동2가 양평벽산블루밍 67000만원
# ...
